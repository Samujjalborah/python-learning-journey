# %% [markdown]
# <a href="https://colab.research.google.com/github/Samujjalborah/python-learning-journey/blob/main/Day7_Dataset_Summary_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 7 - Dataset Summary Report using Pandas
#
# ## Objective
#
# This notebook demonstrates how to load, inspect, and summarize a CSV dataset using the Pandas library. It includes exploring the dataset's structure, viewing rows and columns, checking data types, generating descriptive statistics, and identifying missing values to understand the dataset before performing further analysis.
#
# **Developed by:** Samujjal Borah

# %%
import pandas as pd
df = pd.read_csv("students.csv")

# %% [markdown]
# ## Display the First Five Rows

# %%
df.head()
# Out:
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
#
#    Attendance_Percentage      City
# 0                   91.0  Srinagar
# 1                   95.0     Delhi
# 2                   82.0    Mumbai
# 3                   88.0  Srinagar
# 4                   76.0   Lucknow

# %% [markdown]
# last 5 rows

# %%
df.tail()
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 20        1021    Aman Kumar   18  Computer Science   74.0
# 21        1022    Alina Shah   19      Data Science   96.0
# 22        1023   Nikhil Sood   22                AI   78.0
# 23        1024   Maryam Khan   20  Computer Science   85.0
# 24        1025  Reyansh Jain   21      Data Science   80.0
#
#     Attendance_Percentage       City
# 20                   78.0      Delhi
# 21                   98.0   Srinagar
# 22                   83.0       Pune
# 23                   88.0  Hyderabad
# 24                   84.0    Kolkata

# %% [markdown]
# Random Sample

# %%
df.sample(5)
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 17        1018     Manya Rao   22  Computer Science   70.0
# 8         1009    Arjun Nair   18  Computer Science   84.0
# 24        1025  Reyansh Jain   21      Data Science   80.0
# 13        1014    Sana Malik   18                AI   89.0
# 11        1012     Aisha Mir   19  Computer Science   68.0
#
#     Attendance_Percentage       City
# 17                   74.0  Bengaluru
# 8                    86.0      Kochi
# 24                   84.0    Kolkata
# 13                   92.0        NaN
# 11                   72.0      Delhi

# %% [markdown]
# Shape

# %%
print("Shape:", df.shape)

rows, columns = df.shape

print("Rows:", rows)
print("Columns:", columns)
# Out:
# Shape: (25, 7)
# Rows: 25
# Columns: 7

# %% [markdown]
# Columns

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage',
#        'City'],
#       dtype='object')

# %% [markdown]
# Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %% [markdown]
# Data Types

# %%
df.dtypes
# Out:
# Student_ID                 int64
# Name                      object
# Age                        int64
# Course                    object
# Marks                    float64
# Attendance_Percentage    float64
# City                      object
# dtype: object

# %% [markdown]
# Dataset Infromation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             25 non-null     int64
#  1   Name                   25 non-null     object
#  2   Age                    25 non-null     int64
#  3   Course                 25 non-null     object
#  4   Marks                  24 non-null     float64
#  5   Attendance_Percentage  24 non-null     float64
#  6   City                   24 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# Descriptive Statistics

# %%
df.describe()
# Out:
#         Student_ID        Age      Marks  Attendance_Percentage
# count    25.000000  25.000000  24.000000              24.000000
# mean   1013.000000  20.000000  82.250000              87.083333
# std       7.359801   1.414214   8.689074               7.252686
# min    1001.000000  18.000000  68.000000              72.000000
# 25%    1007.000000  19.000000  75.500000              82.750000
# 50%    1013.000000  20.000000  82.500000              88.000000
# 75%    1019.000000  21.000000  89.250000              92.250000
# max    1025.000000  23.000000  96.000000              98.000000

# %% [markdown]
# Missing Values

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Name                     0
# Age                      0
# Course                   0
# Marks                    1
# Attendance_Percentage    1
# City                     1
# dtype: int64

# %% [markdown]
# # Observations
#
# - Total number of rows: **25**
# - Total number of columns: **7**
# - The dataset contains student information such as Student ID, Name, Age, Course, Marks, Attendance Percentage, and City.
# - Numerical columns are **Student_ID, Age, Marks, Attendance_Percentage**.
# - Categorical columns are **Name, Course, and City**.
# - Missing values are present in the **Marks**, **Attendance_Percentage**, and **City** columns (one missing value in each).
# - The dataset is suitable for further preprocessing and analysis.

# %% [markdown]
# # Conclusion
#
# The dataset was successfully loaded and explored using Pandas. Functions such as `head()`, `tail()`, `sample()`, `shape`, `columns`, `index`, `dtypes`, `info()`, `describe()`, and `isnull()` were used to understand its structure and characteristics. The dataset contains **25 rows** and **7 columns**, with a few missing values that can be handled during data preprocessing.

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'students.csv', 'sample_data']
