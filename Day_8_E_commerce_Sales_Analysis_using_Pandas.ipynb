# %% [markdown]
# <a href="https://colab.research.google.com/github/Samujjalborah/python-learning-journey/blob/main/Day_8_E_commerce_Sales_Analysis_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 8 - E-commerce Sales Analysis using Pandas
#
# ## Objective
#
# This notebook analyzes an e-commerce sales dataset using the Pandas library. The analysis includes data selection, filtering, sorting, grouping, aggregation, and statistical summaries to understand sales performance across different categories, cities, products, and payment methods.
#
# **Developed by:** Samujjal Borah

# %%
import pandas as pd
df=pd.read_csv('ecommerce_sales.csv')
df
# Out:
#     Order_ID  Order_Date      Customer       City Region        Category  \
# 0       1001  2026-02-27     Kabir Ali  Hyderabad  South     Electronics
# 1       1002  2026-01-24  Aditya Verma      Jammu  North          Sports
# 2       1003  2026-04-18    Sara Ahmed    Chennai  South     Electronics
# 3       1004  2026-03-13     Kabir Ali    Lucknow  North     Electronics
# 4       1005  2026-03-30   Priya Menon      Jammu  North     Electronics
# ..       ...         ...           ...        ...    ...             ...
# 95      1096  2026-01-26  Aditya Verma      Kochi  South          Sports
# 96      1097  2026-02-02    Arjun Nair     Mumbai   West        Clothing
# 97      1098  2026-01-04     Yusuf Dar  Bengaluru  South  Home & Kitchen
# 98      1099  2026-03-06   Hiba Sheikh  Ahmedabad   West           Books
# 99      1100  2026-02-08     Kabir Ali       Pune   West           Books
#
#                     Product  Quantity  Unit_Price  Discount_Percent  \
# ...

# %% [markdown]
# ## Display First Five Rows

# %%
df.head()
# Out:
#    Order_ID  Order_Date      Customer       City Region     Category  \
# 0      1001  2026-02-27     Kabir Ali  Hyderabad  South  Electronics
# 1      1002  2026-01-24  Aditya Verma      Jammu  North       Sports
# 2      1003  2026-04-18    Sara Ahmed    Chennai  South  Electronics
# 3      1004  2026-03-13     Kabir Ali    Lucknow  North  Electronics
# 4      1005  2026-03-30   Priya Menon      Jammu  North  Electronics
#
#                Product  Quantity  Unit_Price  Discount_Percent  Total_Sales  \
# 0  Wireless Headphones         3        1499                 0      4497.00
# 1        Running Shoes         1        2799                 0      2799.00
# 2           Power Bank         2        1199                15      2038.30
# 3  Mechanical Keyboard         4        2499                 5      9496.20
# 4          Smart Watch         1        3299                 5      3134.05
#
#    Rating    Payment_Method
# 0     3.8  Cash on Delivery
# 1     4.1  Cash on Delivery
# ...

# %% [markdown]
# ## Display Last Five Rows

# %%
df.tail()
# Out:
#     Order_ID  Order_Date      Customer       City Region        Category  \
# 95      1096  2026-01-26  Aditya Verma      Kochi  South          Sports
# 96      1097  2026-02-02    Arjun Nair     Mumbai   West        Clothing
# 97      1098  2026-01-04     Yusuf Dar  Bengaluru  South  Home & Kitchen
# 98      1099  2026-03-06   Hiba Sheikh  Ahmedabad   West           Books
# 99      1100  2026-02-08     Kabir Ali       Pune   West           Books
#
#                     Product  Quantity  Unit_Price  Discount_Percent  \
# 95             Dumbbell Set         5        1999                 5
# 96                  T-Shirt         1         799                15
# 97          Electric Kettle         4        1499                 0
# 98  Machine Learning Basics         2         999                 0
# 99    Data Science Handbook         5         899                 0
#
#     Total_Sales  Rating Payment_Method
# 95      9495.25     4.2    Credit Card
# ...

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          100 non-null    int64
#  1   Order_Date        100 non-null    object
#  2   Customer          100 non-null    object
#  3   City              100 non-null    object
#  4   Region            100 non-null    object
#  5   Category          100 non-null    object
#  6   Product           100 non-null    object
#  7   Quantity          100 non-null    int64
#  8   Unit_Price        100 non-null    int64
#  9   Discount_Percent  100 non-null    int64
#  10  Total_Sales       100 non-null    float64
#  11  Rating            100 non-null    float64
#  12  Payment_Method    100 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 10.3+ KB

# %% [markdown]
# ## Dataset Shape

# %%
print(df.shape)
# Out:
# (100, 13)

# %% [markdown]
# ## Column Names

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer', 'City', 'Region', 'Category',
#        'Product', 'Quantity', 'Unit_Price', 'Discount_Percent', 'Total_Sales',
#        'Rating', 'Payment_Method'],
#       dtype='object')

# %% [markdown]
# ## Select Required Columns

# %%
df[["Customer","City","Category","Product","Total_Sales"]].head()
# Out:
#        Customer       City     Category              Product  Total_Sales
# 0     Kabir Ali  Hyderabad  Electronics  Wireless Headphones      4497.00
# 1  Aditya Verma      Jammu       Sports        Running Shoes      2799.00
# 2    Sara Ahmed    Chennai  Electronics           Power Bank      2038.30
# 3     Kabir Ali    Lucknow  Electronics  Mechanical Keyboard      9496.20
# 4   Priya Menon      Jammu  Electronics          Smart Watch      3134.05

# %% [markdown]
# ## Select Required Columns

# %%
df[["Customer","City","Category","Product","Total_Sales"]].head()
# Out:
#        Customer       City     Category              Product  Total_Sales
# 0     Kabir Ali  Hyderabad  Electronics  Wireless Headphones      4497.00
# 1  Aditya Verma      Jammu       Sports        Running Shoes      2799.00
# 2    Sara Ahmed    Chennai  Electronics           Power Bank      2038.30
# 3     Kabir Ali    Lucknow  Electronics  Mechanical Keyboard      9496.20
# 4   Priya Menon      Jammu  Electronics          Smart Watch      3134.05

# %% [markdown]
# ## Filter Orders Above ₹5000

# %%
df[df["Total_Sales"]>5000]
# Out:
#     Order_ID  Order_Date       Customer         City Region        Category  \
# 3       1004  2026-03-13      Kabir Ali      Lucknow  North     Electronics
# 7       1008  2026-04-27     Aman Kumar        Jammu  North        Clothing
# 9       1010  2026-03-11     Aman Kumar        Kochi  South        Clothing
# 10      1011  2026-03-22      Rahul Das    Hyderabad  South  Home & Kitchen
# 12      1013  2026-03-09    Maryam Khan      Lucknow  North        Clothing
# 13      1014  2026-02-05      Dev Patel       Jaipur  North          Sports
# 16      1017  2026-03-17     Sana Malik    Hyderabad  South          Sports
# 18      1019  2026-05-19   Reyansh Jain      Chennai  South        Clothing
# 27      1028  2026-04-19     Sana Malik   Chandigarh  North     Electronics
# 28      1029  2026-01-28     Sara Ahmed    Hyderabad  South     Electronics
# 32      1033  2026-06-28    Maryam Khan         Pune   West  Home & Kitchen
# ...

# %% [markdown]
# ## Filter Electronics Category

# %%
df[df["Category"]=="Electronics"]
# Out:
#     Order_ID  Order_Date       Customer         City Region     Category  \
# 0       1001  2026-02-27      Kabir Ali    Hyderabad  South  Electronics
# 2       1003  2026-04-18     Sara Ahmed      Chennai  South  Electronics
# 3       1004  2026-03-13      Kabir Ali      Lucknow  North  Electronics
# 4       1005  2026-03-30    Priya Menon        Jammu  North  Electronics
# 14      1015  2026-06-24     Sana Malik      Kolkata   East  Electronics
# 25      1026  2026-05-12     Sara Ahmed   Chandigarh  North  Electronics
# 27      1028  2026-04-19     Sana Malik   Chandigarh  North  Electronics
# 28      1029  2026-01-28     Sara Ahmed    Hyderabad  South  Electronics
# 36      1037  2026-06-02      Zoya Khan         Pune   West  Electronics
# 46      1047  2026-02-07     Sana Malik    Bengaluru  South  Electronics
# 50      1051  2026-04-28      Aisha Mir  Bhubaneswar   East  Electronics
# 51      1052  2026-03-13    Rohan Mehta   Chandigarh  North  Electronics
# ...

# %% [markdown]
# ## Sort by Highest Sales

# %%
df.sort_values(by="Total_Sales",ascending=False).head(10)
# Out:
#     Order_ID  Order_Date      Customer        City Region        Category  \
# 48      1049  2026-03-02  Ishita Gupta      Mumbai   West          Sports
# 52      1053  2026-01-08  Ananya Singh   Hyderabad  South          Sports
# 84      1085  2026-01-28    Sana Malik   Hyderabad  South  Home & Kitchen
# 89      1090  2026-05-13  Aditya Verma     Lucknow  North          Sports
# 12      1013  2026-03-09   Maryam Khan     Lucknow  North        Clothing
# 47      1048  2026-06-24    Sara Ahmed     Lucknow  North  Home & Kitchen
# 69      1070  2026-06-30  Aditya Verma       Delhi  North        Clothing
# 79      1080  2026-05-25  Aditya Verma       Delhi  North        Clothing
# 51      1052  2026-03-13   Rohan Mehta  Chandigarh  North     Electronics
# 3       1004  2026-03-13     Kabir Ali     Lucknow  North     Electronics
#
#                 Product  Quantity  Unit_Price  Discount_Percent  Total_Sales  \
# ...

# %% [markdown]
# ## Sort by Rating

# %%
df.sort_values(by="Rating",ascending=False).head(10)
# Out:
#     Order_ID  Order_Date      Customer        City Region        Category  \
# 24      1025  2026-01-02   Rohan Mehta     Chennai  South          Sports
# 35      1036  2026-06-02   Rohan Mehta    Srinagar  North          Sports
# 47      1048  2026-06-24    Sara Ahmed     Lucknow  North  Home & Kitchen
# 37      1038  2026-03-08  Aditya Verma        Pune   West          Sports
# 55      1056  2026-04-21   Rohan Mehta    Srinagar  North          Sports
# 90      1091  2026-06-26   Hiba Sheikh       Kochi  South           Books
# 73      1074  2026-03-28    Alina Shah     Lucknow  North           Books
# 60      1061  2026-05-12    Alina Shah   Bengaluru  South           Books
# 59      1060  2026-04-24   Karan Joshi        Pune   West          Sports
# 62      1063  2026-04-17    Aman Kumar  Chandigarh  North           Books
#
#                Product  Quantity  Unit_Price  Discount_Percent  Total_Sales  \
# 24            Football         5         799                 0      3995.00
# ...

# %% [markdown]
# ## Sales by Category

# %%
df.groupby("Category")["Total_Sales"].sum()
# Out:
# Category
# Books              36792.40
# Clothing           69028.20
# Electronics        92086.00
# Home & Kitchen    113329.90
# Sports            136026.45
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## Sales by City

# %%
df.groupby("City")["Total_Sales"].sum()
# Out:
# City
# Ahmedabad      14788.70
# Bengaluru      13524.30
# Bhubaneswar     6598.00
# Chandigarh     34539.65
# Chennai        47493.20
# Delhi          30882.80
# Hyderabad      59076.45
# Jaipur         25534.00
# Jammu          16059.75
# Kochi          37257.50
# Kolkata        20169.00
# Lucknow        46194.65
# Mumbai         41457.80
# Pune           41908.55
# Srinagar       11778.60
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## Sales by Product

# %%
df.groupby("Product")["Total_Sales"].sum()
# Out:
# Product
# Atomic Habits              11590.65
# Coffee Maker               51610.25
# Cricket Bat                41483.40
# Data Science Handbook       4495.00
# Dumbbell Set               30184.90
# Electric Kettle            26382.40
# Football                   10307.10
# Hoodie                      7675.20
# Jacket                     47106.15
# Jeans                       6456.60
# Machine Learning Basics     5694.30
# Mechanical Keyboard        26489.40
# Mixer Grinder              25341.55
# Power Bank                  6474.60
# Python Programming          7527.45
# Running Shoes              41285.25
# Smart Watch                15670.25
# T-Shirt                     7790.25
# The Alchemist               7485.00
# Water Bottle                9995.70
# Wireless Headphones        33877.40
# Wireless Mouse              9574.35
# Yoga Mat                   12765.80
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## Sales by Payment Method

# %%
df.groupby("Payment_Method")["Total_Sales"].sum()
# Out:
# Payment_Method
# Cash on Delivery     50123.30
# Credit Card         106540.25
# Debit Card           98064.90
# Net Banking          96371.25
# UPI                  96163.25
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## Total Sales

# %%
print(df["Total_Sales"].sum())
# Out:
# 447262.95000000007

# %% [markdown]
# ## Average Sales

# %%
print(df["Total_Sales"].mean())
# Out:
# 4472.629500000001

# %% [markdown]
# ## Highest Sale

# %%
print(df["Total_Sales"].max())
# Out:
# 13995.0

# %% [markdown]
# ## Lowest Sale

# %%
print(df["Total_Sales"].min())
# Out:
# 449.1

# %% [markdown]
# ## Total Quantity Sold

# %%
print(df["Quantity"].sum())
# Out:
# 294

# %% [markdown]
# ## Number of Orders

# %%
print(df["Order_ID"].count())
# Out:
# 100

# %% [markdown]
# ## Top 5 Products

# %%
df.groupby("Product")["Total_Sales"].sum().sort_values(ascending=False).head(5)
# Out:
# Product
# Coffee Maker           51610.25
# Jacket                 47106.15
# Cricket Bat            41483.40
# Running Shoes          41285.25
# Wireless Headphones    33877.40
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## Top 5 Categories

# %%
df.groupby("Category")["Total_Sales"].sum().sort_values(ascending=False).head()
# Out:
# Category
# Sports            136026.45
# Home & Kitchen    113329.90
# Electronics        92086.00
# Clothing           69028.20
# Books              36792.40
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## Top 5 Cities

# %%
df.groupby("City")["Total_Sales"].sum().sort_values(ascending=False).head()
# Out:
# City
# Hyderabad    59076.45
# Chennai      47493.20
# Lucknow      46194.65
# Pune         41908.55
# Mumbai       41457.80
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ## Payment Method Analysis

# %%
df.groupby("Payment_Method").agg({
    "Total_Sales":"sum",
    "Order_ID":"count"
})
# Out:
#                   Total_Sales  Order_ID
# Payment_Method
# Cash on Delivery     50123.30        15
# Credit Card         106540.25        22
# Debit Card           98064.90        20
# Net Banking          96371.25        17
# UPI                  96163.25        26

# %% [markdown]
# # Observations
#
# - The dataset contains **100 orders** with sales from multiple cities and product categories.
# - Electronics and Sports generate a significant share of total sales.
# - A few products contribute much more revenue than others, making them top-performing products.
# - UPI, Credit Card, Debit Card, Cash on Delivery, and Net Banking are all used as payment methods.
# - Higher-value orders generally involve Electronics and Sports products.
# - The analysis helps identify top-performing cities, categories, products, and customer purchasing patterns.

# %% [markdown]
# # Conclusion
#
# Using Pandas, the e-commerce dataset was successfully analyzed through selection, filtering, sorting, grouping, and aggregation techniques. The notebook identified overall sales performance, top-selling products, leading categories, city-wise sales, payment method trends, and key business insights. These analyses can support better business decisions and future sales strategies.
