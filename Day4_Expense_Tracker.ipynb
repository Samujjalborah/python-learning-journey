# %% [markdown]
# <a href="https://colab.research.google.com/github/Samujjalborah/python-learning-journey/blob/main/Day4_Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 4 - Expense Tracking System
#
# ## Objective
#
# This project is a menu-driven Expense Tracker Application developed in Python. It allows users to record, view, and summarize daily expenses while storing the data permanently in a CSV file.
#
# ## Features
#
# - Add a new expense
# - View all recorded expenses
# - Calculate the total amount spent
# - Display category-wise spending summary
# - Store and retrieve expense records using a CSV file
# - Handle invalid input using exception handling
#
# **Developed by:** Samujjal Borah

# %%
import csv
import os
FILE_NAME = "expenses.csv"

# Create the CSV file if it doesn't exist
def create_file():
    if not os.path.exists(FILE_NAME):
        with open(FILE_NAME, mode="w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["Date", "Category", "Amount", "Note"])

# Create the file before using it
create_file()

expenses = []

def add_expense():

    try:

        expense = {
            "date": input("Enter Date (DD/MM/YYYY): "),
            "category": input("Enter Category: "),
            "amount": float(input("Enter Amount: ")),
            "note": input("Enter Note: ")
        }

    except ValueError:
        print("Invalid amount! Please enter numbers only.")
        return

    expenses.append(expense)

    with open(FILE_NAME, mode="a", newline="") as file:
        writer = csv.writer(file)

        writer.writerow([
            expense["date"],
            expense["category"],
            expense["amount"],
            expense["note"]
        ])

    print("Expense added successfully!")

# Test the function
def view_expenses():

    total = 0

    with open(FILE_NAME, mode="r") as file:

        reader = csv.reader(file)

        next(reader)

        print("\n===== ALL EXPENSES =====")

        for row in reader:

            print(f"Date     : {row[0]}")
            print(f"Category : {row[1]}")
            print(f"Amount   : ₹{row[2]}")
            print(f"Note     : {row[3]}")
            print("--------------------------")

            total += float(row[2])

    print(f"\nTotal Amount Spent: ₹{total}")
def category_summary():

    summary = {}

    with open(FILE_NAME, mode="r") as file:

        reader = csv.reader(file)

        next(reader)

        for row in reader:

            category = row[1]
            amount = float(row[2])
            if category in summary:
                summary[category] += amount
            else:
                summary[category] = amount
    print("\n===== CATEGORY SUMMARY =====")

    for category, amount in summary.items():
      print(f"{category}: ₹{amount}")
'''# 👇 Then your testing code
add_expense()
view_expenses()

print("\nExpenses stored in memory:")
print(expenses)'''
while True:

    print("\n===== EXPENSE TRACKER =====")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Category Summary")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_expense()

    elif choice == "2":
        view_expenses()

    elif choice == "3":
        category_summary()

    elif choice == "4":
        print("Thank you for using Expense Tracker.")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Exit
# Enter your choice: 1
# Enter Date (DD/MM/YYYY): 23/11/2026
# Enter Category: Food
# Enter Amount: ^99
# Invalid amount! Please enter numbers only.
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Exit
# Enter your choice: 1
# Enter Date (DD/MM/YYYY): 23/11/2026
# Enter Category: Food
# Enter Amount: 699
# Enter Note: Lunch
# Expense added successfully!
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Exit
# Enter your choice: 1
# Enter Date (DD/MM/YYYY): abc
# Enter Category: abc
# Enter Amount: abc
# Invalid amount! Please enter numbers only.
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Exit
# Enter your choice: 4
# Thank you for using Expense Tracker.
